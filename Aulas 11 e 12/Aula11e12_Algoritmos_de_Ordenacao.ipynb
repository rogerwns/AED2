# %% [markdown]
# ![Algoritmos e Estrutura de Dados II - Prof Piva](AED2_banner.jpg)

# %% [markdown]
# ## Aulas 11 e 12 -  Algoritmos de ordenação

# %% [markdown]
# ![Comparação de Algoritmos de Ordenação](algoritmos.png)

# %% [markdown]
# ## Bubble sort  ( O(n**2) )

# %%
import numpy as np

# %%
def bubble_sort(vetor):
  n = len(vetor)

  for i in range(n):
    for j in range(0, n - i - 1):
      if vetor[j] > vetor[j + 1]:
        vetor[j], vetor[j + 1] = vetor[j+1], vetor[j]
          
  return vetor

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))
vetor = vet

# %%
# Vetor não ordenado
print(vet)
# Out:
# [28, 92, 257, 619, 774, 257, 97, 56, 940, 689, 717, 60, 84, 154, 12, 686, 597, 997, 601, 777, 980, 175, 339, 578, 445, 193, 378, 827, 426, 296, 150, 301, 389, 992, 114, 369, 104, 827, 178, 678, 149, 913, 959, 526, 255, 772, 593, 836, 27, 530, 478, 315, 545, 839, 152, 631, 424, 314, 882, 329, 576, 211, 463, 727, 270, 2, 352, 716, 287, 764, 537, 825, 839, 659, 744, 339, 406, 375, 377, 864, 153, 640, 267, 159, 441, 851, 572, 875, 686, 785, 824, 129, 89, 4, 850, 357, 777, 210, 275, 554, 403, 331, 765, 384, 660, 422, 995, 407, 327, 812, 30, 213, 702, 346, 263, 656, 89, 561, 532, 248, 413, 949, 911, 457, 987, 435, 524, 61, 609, 20, 167, 28, 481, 821, 420, 323, 902, 24, 740, 787, 122, 572, 572, 116, 79, 655, 554, 850, 906, 453, 119, 298, 243, 889, 435, 769, 24, 415, 700, 68, 953, 513, 339, 190, 891, 208, 919, 756, 154, 748, 778, 272, 711, 447, 590, 571, 771, 178, 703, 881, 18, 225, 334, 634, 901, 333, 842, 194, 340, 848, 359, 532, 449, 813, 538, 670, 995, 499, 280, 8, 32, 935, 48, 709, 19, 65, 734, 984, 998, 621, 398, 373, 152, 214, 217, 441, 281, 909, 435, 995, 444, 692, 930, 676, 348, 429, 240, 971, 425, 780, 35, 175, 789, 770, 913, 175, 9, 807, 768, 886, 900, 740, 992, 749, 870, 915, 370, 521, 841, 542, 126, 337, 952, 79, 54, 536, 713, 437, 214, 201, 277, 647, 558, 147, 939, 63, 134, 132, 660, 148, 914, 109, 98, 135, 484, 228, 708, 162, 975, 334, 874, 658, 148, 367, 158, 869, 793, 304, 769, 661, 990, 531, 701, 863, 221, 200, 366, 509, 749, 109, 136, 880, 573, 403, 284, 733, 693, 117, 414, 623, 325, 424, 105, 666, 501, 218, 893, 720, 116, 95, 113, 890, 416, 944, 384, 916, 332, 468, 608, 303, 952, 684, 189, 666, 683, 786, 134, 827, 60, 937, 35, 645, 395, 420, 7, 337, 571, 344, 51, 346, 562, 86, 819, 799, 682, 289, 892, 595, 241, 163, 845, 219, 790, 159, 968, 750, 40, 587, 478, 345, 712, 178, 409, 610, 977, 534, 927, 810, 24
 33, 799, 318, 451, 211, 390, 812, 920, 577, 540, 521, 618, 564, 721, 334, 272, 92, 482, 740, 442, 943, 839, 658, 60, 297, 825, 804, 674, 13, 105, 987, 151, 366, 990, 249, 329, 755, 930, 106, 227, 844, 699, 321, 612, 495, 345, 864, 832, 179, 80, 710, 456, 890, 822, 782, 850, 705, 229, 955, 504, 749, 138, 604, 638, 350, 343, 955, 710, 244, 319, 464, 150, 89, 891, 477, 923, 626, 759, 189, 895, 894, 42, 938, 876, 803, 259, 940, 762, 954, 929, 450, 535, 109, 372, 773, 518, 57, 97, 725, 518, 578, 803, 808, 781, 245, 895, 241, 850, 209, 474, 954, 865, 304, 241, 821, 920, 497, 551, 573, 267, 458, 625, 907, 857, 429, 870, 685, 891, 212, 905, 857, 627, 729, 320, 412, 921, 617, 528, 795, 207, 571, 753, 654, 153, 849, 153, 460, 702, 800, 501, 425, 789, 361, 625, 259, 684, 467, 311, 194, 974, 891, 436, 18, 891, 812, 786, 317, 991, 438, 47, 134, 623, 564, 434, 747, 261, 739, 583, 151, 694, 800, 918, 844, 351, 368, 687, 871, 506, 949, 759, 798, 543, 940, 853, 924, 966, 368, 140, 742, 168, 791, 954, 786, 302, 14, 979, 787, 498, 216, 775, 928, 6, 321, 608, 468, 584, 703, 184, 689, 875, 972, 86, 616, 353, 763, 123, 286, 573, 129, 432, 61, 440, 36, 718, 386, 948, 87, 968, 236, 397, 948, 476, 705, 409, 11, 592, 991, 750, 466, 337, 362, 861, 493, 860, 236, 658, 209, 673, 182, 64, 348, 37, 152, 958, 641, 904, 165, 42, 70, 105, 758, 736, 850, 898, 474, 55, 685, 46, 230, 990, 90, 713, 545, 621, 849, 46, 883, 798, 658, 102, 546, 602, 590, 821, 774, 331, 677, 348, 131, 613, 159, 811, 729, 907, 908, 936, 423, 162, 542, 616, 703, 453, 674, 279, 1, 558, 236, 116, ...

# %% [markdown]
# ## Selection sort    ( O(n**2) )

# %%
def selection_sort(vetor):
  n = len(vetor)

  for i in range(n):
    id_minimo = i
    for j in range(i + 1, n):
      if vetor[id_minimo] > vetor[j]:
        id_minimo = j
    temp = vetor[i]
    vetor[i] = vetor[id_minimo]
    vetor[id_minimo] = temp

  return vetor

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit selection_sort(vet)

# %%
# Vetor ordenado
print(vet)

# %% [markdown]
# ## Insertion sort  (  O(n**2) )

# %%
def insertion_sort1(vetor):
    n = len(vetor)
    
    for i in range(1, n):
        marcado = vetor[i]
        
        j = i - 1
        while j >= 0 and marcado < vetor[j]:
            vetor[j + 1] = vetor[j]
            j -= 1
        vetor[j + 1] = marcado
    
    return vetor

# %%
def insertion_sort2(vetor):
    # Percorre cada elemento de L
    for i in range(1, len(vetor)):
        k = i
        # Insere o pivô na posição correta
        while k > 0 and vetor[k] < vetor[k-1]:
            vetor[k], vetor[k-1] = vetor[k-1], vetor[k]
            k = k - 1

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit insertion_sort1(vet)

# %%
# Vetor ordenado
print(vet)

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit insertion_sort2(vet)

# %%
# Vetor ordenado
print(vet)

# %% [markdown]
# ## Shell sort  (  O(n**2)  - O(n log n) )

# %%
# shell sort
def shell_sort1(vetor):
    n = len(vetor)
    h = 1
    while h > 0:
        for i in range(h, n):
            c = vetor[i]
            j = i
            while j >= h and c < vetor[j - h]:
                vetor[j] = vetor[j - h]
                j = j - h
                vetor[j] = c
        h = int(h / 2.2)
    return vetor

# %%
def shell_sort2(vetor):
  intervalo = len(vetor) // 2

  while intervalo > 0:
    for i in range(intervalo, len(vetor)):
      temp = vetor[i]
      j = i
      while j >= intervalo and vetor[j - intervalo] > temp:
        vetor[j] = vetor[j - intervalo]
        j -= intervalo
      vetor[j] = temp
    intervalo //= 2

  return vetor

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit shell_sort1(vet)

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit shell_sort2(vet)

# %%
# Vetor ordenado
print(vet)

# %% [markdown]
# ## Quick sort  (  O(n log n)  mas existem casos O(n**2)  )

# %%
def particao(vetor, inicio, final):
    pivo = vetor[final]
    i = inicio - 1

    for j in range(inicio, final):
        if vetor[j] <= pivo:
            i += 1
            vetor[i], vetor[j] = vetor[j], vetor[i]
        vetor[i + 1], vetor[final] = vetor[final], vetor[i + 1]
    return i + 1

def quick_sort(vetor, inicio=0, final=(len(vetor)-1)):
    if inicio < final:
        posicao = particao(vetor, inicio, final)
        # Esquerda
        quick_sort(vetor, inicio, posicao - 1)
        # Direito
        quick_sort(vetor, posicao + 1, final)
    return vetor

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit quick_sort(vet)

# %%
# Vetor ordenado
print(vet)

# %% [markdown]
# ## Merge sort  ( O(n log n) )

# %%
# merge sort
def merge_sort(vetor):
    if len(vetor) > 1:
        divisao = len(vetor) // 2
        esquerda = vetor[:divisao].copy()
        direita = vetor[divisao:].copy()

        merge_sort(esquerda)
        merge_sort(direita)

        i, j, k = 0, 0, 0

        # Ordena esquerda e direita
        while i < len(esquerda) and j < len(direita):
            if esquerda[i] < direita[j]:
                vetor[k] = esquerda[i]
                i += 1
            else:
                vetor[k] = direita[j]
                j += 1
            k += 1

        # Ordenação final
        while i < len(esquerda):
            vetor[k] = esquerda[i]
            i += 1
            k += 1
        while j < len(direita):
            vetor[k] = direita[j]
            j += 1
            k += 1
    return vetor

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit merge_sort(vet)

# %%
# Vetor ordenado
print(vet)

# %% [markdown]
# ## Comparativo entre algoritmos

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
type(vet)

# %%
vet = np.array(vet)
type(vet)

# %%
len(vet)

# %%
# %timeit bubble_sort(vet.copy())

# %%
# %timeit selection_sort(vet.copy())

# %%
# %timeit insertion_sort2(vet.copy())

# %%
# %timeit shell_sort1(vet.copy())

# %%
# %timeit quick_sort(vet.copy(), 0, len(vetor) - 1)

# %%
# %timeit merge_sort(vet.copy())

# %% [markdown]
# ## Fim das Aulas 11 e 12
